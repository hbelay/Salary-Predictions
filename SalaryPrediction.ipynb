# %% [markdown]
# # Salary Predictions Based on Job Descriptions

# %%
__author__ = "Haimanot"
__email__ = "haimanb1@umbc.edu"

# %% [markdown]
# # Part 1 - DEFINE

# %% [markdown]
# ### ---- 1 Define the problem ----

# %% [markdown]
# This is a a data science project and the goal is to examine a set of job postings with salaries and then predict salaries for a new set of job postings.

# %%
#import your libraries
#import your libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib  inline
import pandas_profiling

# %% [markdown]
# ## Part 2 - DISCOVER

# %% [markdown]
# ### ---- 2 Load the data ----

# %%
#load the data into a Pandas dataframe
train_feature_df = pd.read_csv('/Users/haiman/Desktop/DSDJ/Salary-Predictions/data/train_features.csv')
train_target_df = pd.read_csv('/Users/haiman/Desktop/DSDJ/Salary-Predictions/data/train_salaries.csv')
test_feature_df = pd.read_csv('/Users/haiman/Desktop/DSDJ/Salary-Predictions/data/test_features.csv')

# %%
# Merge the features and salaries represented by the data frames train_feature_df & train_target_df respectively on jobId
train_df = pd.merge(train_feature_df, train_target_df, on='jobId')
train_df.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis  salary
# 0   HEALTH               10                   83     130
# 1      WEB                3                   73     101
# 2   HEALTH               10                   38     137
# 3     AUTO                8                   17     142
# 4  FINANCE                8                   16     163

# %% [markdown]
# Running the following single line of code will create an HTML EDA report of the data. The first part of the HTML EDA report will contain an overview section providing basic information (number of observations, number of variables, data types and so on.). It will also output a list of warnings telling you where to double-check the data and potentially focus your cleaning efforts on.

# %%
train_df.profile_report()
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
#delete the original files which are merged above(to save memory)
del train_feature_df
del train_target_df

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
# jobId                  1000000 non-null object
# companyId              1000000 non-null object
# jobType                1000000 non-null object
# degree                 1000000 non-null object
# major                  1000000 non-null object
# industry               1000000 non-null object
# yearsExperience        1000000 non-null int64
# milesFromMetropolis    1000000 non-null int64
# salary                 1000000 non-null int64
# dtypes: int64(3), object(6)
# memory usage: 76.3+ MB

# %%
# the describe() function only used for numerical features
train_df.describe()
# Out:
#        yearsExperience  milesFromMetropolis          salary
# count   1000000.000000       1000000.000000  1000000.000000
# mean         11.992386            49.529260      116.061818
# std           7.212391            28.877733       38.717936
# min           0.000000             0.000000        0.000000
# 25%           6.000000            25.000000       88.000000
# 50%          12.000000            50.000000      114.000000
# 75%          18.000000            75.000000      141.000000
# max          24.000000            99.000000      301.000000

# %% [markdown]
# ### ---- 3 Clean the data ----

# %%
#look for duplicate data, invalid data (e.g. salaries <=0), or corrupt data and remove it
stat = train_df.salary.describe()
print(stat)
IQR = stat['75%'] - stat['25%']
upper = stat['75%'] + 1.5 * IQR
lower = stat['25%'] - 1.5 * IQR
print('The upper and lower bounds for suspected outliers are {} and {}.'.format(upper, lower))
# Out:
# count    1000000.000000
# mean         116.061818
# std           38.717936
# min            0.000000
# 25%           88.000000
# 50%          114.000000
# 75%          141.000000
# max          301.000000
# Name: salary, dtype: float64
# The upper and lower bounds for suspected outliers are 220.5 and 8.5.

# %%
#check potential outlier below lower bound
train_df[train_df.salary < 8.5]
# Out:
#                    jobId companyId         jobType       degree        major  \
# 30559   JOB1362684438246    COMP44          JUNIOR     DOCTORAL         MATH
# 495984  JOB1362684903671    COMP34          JUNIOR         NONE         NONE
# 652076  JOB1362685059763    COMP25             CTO  HIGH_SCHOOL         NONE
# 816129  JOB1362685223816    COMP42         MANAGER     DOCTORAL  ENGINEERING
# 828156  JOB1362685235843    COMP40  VICE_PRESIDENT      MASTERS  ENGINEERING
#
#        industry  yearsExperience  milesFromMetropolis  salary
# 30559      AUTO               11                    7       0
# 495984      OIL                1                   25       0
# 652076     AUTO                6                   60       0
# 816129  FINANCE               18                    6       0
# 828156      WEB                3                   29       0

# %%
#check potential outlier above upper bound
train_df.loc[train_df.salary > 222.5, 'jobType'].value_counts()
# Out:
# CEO               2893
# CFO               1308
# CTO               1298
# VICE_PRESIDENT     520
# MANAGER            188
# SENIOR              50
# JUNIOR              16
# Name: jobType, dtype: int64

# %%
# Check most suspicious potential outliers above upper bound
train_df[(train_df.salary > 222.5) & (train_df.jobType == 'JUNIOR')]
# Out:
#                    jobId companyId jobType     degree        major industry  \
# 1222    JOB1362684408909    COMP40  JUNIOR    MASTERS      COMPSCI      OIL
# 27710   JOB1362684435397    COMP21  JUNIOR   DOCTORAL  ENGINEERING      OIL
# 31355   JOB1362684439042    COMP45  JUNIOR   DOCTORAL      COMPSCI  FINANCE
# 100042  JOB1362684507729    COMP17  JUNIOR   DOCTORAL     BUSINESS  FINANCE
# 160333  JOB1362684568020    COMP18  JUNIOR   DOCTORAL     BUSINESS  FINANCE
# 303778  JOB1362684711465    COMP51  JUNIOR    MASTERS  ENGINEERING      WEB
# 348354  JOB1362684756041    COMP56  JUNIOR   DOCTORAL  ENGINEERING      OIL
# 500739  JOB1362684908426    COMP40  JUNIOR   DOCTORAL  ENGINEERING      OIL
# 627534  JOB1362685035221     COMP5  JUNIOR   DOCTORAL  ENGINEERING      OIL
# 645555  JOB1362685053242    COMP36  JUNIOR   DOCTORAL     BUSINESS  FINANCE
# 685775  JOB1362685093462    COMP38  JUNIOR  BACHELORS  ENGINEERING      OIL
# ...

# %%
# Remove data with zero salaries
train_df = train_df[train_df.salary > 8.5]
train_df.count()
# Out:
# jobId                  999995
# companyId              999995
# jobType                999995
# degree                 999995
# major                  999995
# industry               999995
# yearsExperience        999995
# milesFromMetropolis    999995
# salary                 999995
# dtype: int64

# %% [markdown]
# ### ---- 4 Explore the data (EDA) ----

# %%
#summarize each feature variable
#summarize the target variable
#look for correlation between each feature and the target
#look for correlation between features

# %% [markdown]
# ### ---- 5 Establish a baseline ----

# %%
#select a reasonable metric (MSE in this case)
#create an extremely simple model and measure its efficacy
#e.g. use "average salary" for each industry as your model and then measure MSE
#during 5-fold cross-validation

# %% [markdown]
# ### ---- 6 Hypothesize solution ----

# %%
#brainstorm 3 models that you think may improve results over the baseline model based
#on your

# %% [markdown]
# Brainstorm 3 models that you think may improve results over the baseline model based on your EDA and explain why they're reasonable solutions here.
#
# Also write down any new features that you think you should try adding to the model based on your EDA, e.g. interaction variables, summary statistics for each group, etc

# %% [markdown]
# ## Part 3 - DEVELOP

# %% [markdown]
# You will cycle through creating features, tuning models, and training/validing models (steps 7-9) until you've reached your efficacy goal
#
# #### Your metric will be MSE and your goal is:
#  - <360 for entry-level data science roles
#  - <320 for senior data science roles

# %% [markdown]
# ### ---- 7 Engineer features  ----

# %%
#make sure that data is ready for modeling
#create any new features needed to potentially enhance model

# %% [markdown]
# ### ---- 8 Create models ----

# %%
#create and tune the models that you brainstormed during part 2

# %% [markdown]
# ### ---- 9 Test models ----

# %%
#do 5-fold cross validation on models and measure MSE

# %% [markdown]
# ### ---- 10 Select best model  ----

# %%
#select the model with the lowest error as your "prodcuction" model

# %% [markdown]
# ## Part 4 - DEPLOY

# %% [markdown]
# ### ---- 11 Automate pipeline ----

# %%
#write script that trains model on entire training set, saves model to disk,
#and scores the "test" dataset

# %% [markdown]
# ### ---- 12 Deploy solution ----

# %%
#save your prediction to a csv file or optionally save them as a table in a SQL database
#additionally, you want to save a visualization and summary of your prediction and feature importances
#these visualizations and summaries will be extremely useful to business stakeholders

# %% [markdown]
# ### ---- 13 Measure efficacy ----

# %% [markdown]
# We'll skip this step since we don't have the outcomes for the test data
